# %%
# Task : Occupation
# Step 1: Import libraries
import pandas as pd

# %%
# Step 2 : Retrieve dataset
# Step 3 : Assign to variable users
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
# display value of 5 rows data
users.head(5)
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#Step 4: Discover what is the mean age per occupation
users[['age','occupation']].mean()
# Out:
# age    34.051962
# dtype: float64

# %%
# Step 5 : Discover the Male ratio occupaion and sort it from the most to the least
users[users.gender=='M'].sort_values
# Out:
# <bound method DataFrame.sort_values of      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 18        19   40      M      librarian    02138
# 20        21   26      M         writer    30068
# 21        22   25      M         writer    40206
# 24        25   39      M       engineer    55107
# 25        26   49      M       engineer    21044
# ...

# %%
# Step 6 : For each occupation, calculate the minimum and maximum ages
import numpy as np
ages_min = users.groupby(['user_id']).agg(['min','max'])
ages_min
# Out:
#         age     gender         occupation                zip_code
#         min max    min max            min            max      min    max
# user_id
# 1        24  24      M   M     technician     technician    85711  85711
# 2        53  53      F   F          other          other    94043  94043
# 3        23  23      M   M         writer         writer    32067  32067
# 4        24  24      M   M     technician     technician    43537  43537
# 5        33  33      F   F          other          other    15213  15213
# 6        42  42      M   M      executive      executive    98101  98101
# 7        57  57      M   M  administrator  administrator    91344  91344
# 8        36  36      M   M  administrator  administrator    05201  05201
# 9        29  29      M   M        student        student    01002  01002
# 10       53  53      M   M         lawyer         lawyer    90703  90703
# 11       39  39      F   F          other          other    30329  30329
# ...

# %%
ages_max = users['age'].max()
ages_max

# Step 7 : For each combination of occupation and gender, calculate the mean age
# Out:
# 73

# %%
# Step 8 : For each occupation present the percentage of woman and men
